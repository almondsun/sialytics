# %% [markdown]
# # SIAlytics
#
# Esta sesión abre Chromium para autenticación manual y genera un XLSX local. **No escriba credenciales en este notebook.** Sialytics abortará si no puede probar que todas las secciones fueron cargadas completamente.

# %%
from sialytics.workflow import run_interactive

# %%
archivo = await run_interactive()
print(f"Archivo generado: {archivo}")
